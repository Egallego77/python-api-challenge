# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# Out:
# Processing c:\users\quiqu\appdata\local\pip\cache\wheels\30\bd\87\d0d731ee712c34a4d6bace8b1dbf8c8932e22a1625b4a55be4\gmaps-0.9.0-py2.py3-none-any.whl
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\quiqu\anaconda3\lib\site-packages (from gmaps) (5.0.5)
# Collecting geojson>=2.0.0
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\quiqu\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\quiqu\anaconda3\lib\site-packages (from gmaps) (7.19.0)
# Requirement already satisfied: six in c:\users\quiqu\anaconda3\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: ipython-genutils in c:\users\quiqu\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\quiqu\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\quiqu\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\quiqu\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: backcall in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: decorator in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (50.3.1.post20201107)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: pygments in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.7.2)
# Requirement already satisfied: pickleshare in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\quiqu\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\quiqu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\quiqu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\quiqu\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\quiqu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: jupyter-client in c:\users\quiqu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\quiqu\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\quiqu\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\quiqu\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\quiqu\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\quiqu\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: nbconvert in c:\users\quiqu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: prometheus-client in c:\users\quiqu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: jinja2 in c:\users\quiqu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: argon2-cffi in c:\users\quiqu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\quiqu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (19.0.2)
# Requirement already satisfied: Send2Trash in c:\users\quiqu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\quiqu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\quiqu\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: testpath in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: bleach in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.2.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\quiqu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\quiqu\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\quiqu\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.3)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\quiqu\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: packaging in c:\users\quiqu\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in c:\users\quiqu\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: async-generator in c:\users\quiqu\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\quiqu\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: pycparser in c:\users\quiqu\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\quiqu\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import gmaps

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# load the csv file exportted to a DF
city_data_df = pd.read_csv("output_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID                City      Lat      Lng  Max Temp  Humidity  \
# 0        0         henties bay -22.1160  14.2845     81.00        47
# 1        1  havre-saint-pierre  50.2334 -63.5986     33.80        69
# 2        2        punta arenas -53.1500 -70.9167     44.60        81
# 3        3             ushuaia -54.8000 -68.3000     44.60        70
# 4        4      telemaco borba -24.3239 -50.6156     66.76        63
#
#    Cloudiness  Wind Speed Country        Date
# 0          93        1.01     NaN  1618611586
# 1           1        9.22      CA  1618611587
# 2          40       10.36      CL  1618611587
# 3          40       23.02      AR  1618611588
# 4          87        1.88      BR  1618611588

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Heatmap variables
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=5)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrowed_city_df = city_data_df.loc[(city_data_df["Max Temp"] < 80) & (city_data_df["Max Temp"] > 70) \
                                    & (city_data_df["Wind Speed"] < 10) \
                                    & (city_data_df["Cloudiness"] == 0)].dropna()
narrowed_city_df
# Out:
#       City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 42         42         saint-philippe -21.3585   55.7679     77.00        78
# 118       118           saint-pierre -21.3393   55.4781     77.00        78
# 140       140                   atar  20.5169  -13.0499     78.85        16
# 214       214                 riyadh  24.6877   46.7219     73.40        21
# 235       235           saint-joseph -21.3667   55.6167     77.00        78
# 267       267                  moron -34.6534  -58.6198     73.00        74
# 343       343           port hedland -20.3167  118.5667     77.00        53
# 458       458      sao joao da barra -21.6403  -41.0511     75.20        73
# 530       530              kondagaon  19.6000   81.6667     73.92        41
# 591       591                  matay  28.4190   30.7792     75.36        20
# 641       641              saint-leu -21.1500   55.2833     77.00        78
# 663       663     villa constitucion -33.2278  -60.3297     77.00        71
# 738       738                   doha  25.2867   51.5333     73.40        38
# 806       806                emerald -23.5333  148.1667     71.60        68
# 894       894                 safaga  26.7292   33.9365     77.00        16
# 1062     1062          venado tuerto -33.7456  -61.9688     75.00        99
# 1166     1166             hervey bay -25.2986  152.8535     73.00        78
# 1304     1304                   buin -33.7333  -70.7500     77.00        31
# 1344     1344                redmond  47.6740 -122.1215     79.00        32
# 1347     1347                  macae -22.3708  -41.7869     77.00        73
# 1396     1396                guaruja -23.9931  -46.2564     79.00        73
# 1424     1424  conceicao das alagoas -19.9147  -48.3883     78.80        50
# 1822                sawakin      SD  19.1059   37.3321
# 1824                    bam      IR  29.1060   58.3570
# 1918                sharjah      AE  25.3573   55.4033
# 1954                 parana      AR -31.7320  -60.5238
# 1960                carmelo      UY -33.9892  -58.2856
# 1993           dunmore town      BS  25.5000  -76.6500
# 2006                 curico      CL -34.9833  -71.2333
# 2046                   qena      EG  26.1615   32.7183
# 2071             rock sound      BS  24.9000  -76.2000
# 2099               nayagarh      IN  20.1333   85.1000

# %%
# Set parameters to search for a hotel
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key
}

# Iterate through 
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "Hotel" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
    # convert to json
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

hotel_df
# Out:
#                        City Country      Lat       Lng  \
# 42           saint-philippe      RE -21.3585   55.7679
# 118            saint-pierre      RE -21.3393   55.4781
# 140                    atar      MR  20.5169  -13.0499
# 214                  riyadh      SA  24.6877   46.7219
# 235            saint-joseph      RE -21.3667   55.6167
# 267                   moron      AR -34.6534  -58.6198
# 343            port hedland      AU -20.3167  118.5667
# 458       sao joao da barra      BR -21.6403  -41.0511
# 530               kondagaon      IN  19.6000   81.6667
# 591                   matay      EG  28.4190   30.7792
# 641               saint-leu      RE -21.1500   55.2833
# 663      villa constitucion      AR -33.2278  -60.3297
# 738                    doha      QA  25.2867   51.5333
# 806                 emerald      AU -23.5333  148.1667
# 894                  safaga      EG  26.7292   33.9365
# 1062          venado tuerto      AR -33.7456  -61.9688
# 1166             hervey bay      AU -25.2986  152.8535
# 1304                   buin      CL -33.7333  -70.7500
# 1344                redmond      US  47.6740 -122.1215
# 1347                  macae      BR -22.3708  -41.7869
# 1396                guaruja      BR -23.9931  -46.2564
# 1424  conceicao das alagoas      BR -19.9147  -48.3883
# 1473               imbituba      BR -28.2400  -48.6703
# 1574                  lujan      AR -34.5703  -59.1050
# 1680  conceicao do araguaia      BR  -8.2578  -49.2647
# 1733             rio cuarto      AR -33.1307  -64.3499
# 1822                sawakin      SD  19.1059   37.3321
# 1824                    bam      IR  29.1060   58.3570
# 1918                sharjah      AE  25.3573   55.4033
# 1954                 parana      AR -31.7320  -60.5238
# 1960                carmelo      UY -33.9892  -58.2856
# 1993           dunmore town      BS  25.5000  -76.6500
# 2006                 curico      CL -34.9833  -71.2333
# 2046                   qena      EG  26.1615   32.7183
# 2071             rock sound      BS  24.9000  -76.2000
# 2099               nayagarh      IN  20.1333   85.1000
#
#                                 Hotel Name
# 42            Chambres d'hôte "La Trinité"
# 118                          Lindsey Hôtel
# 140                         Oumou Elghoura
# 214                InterContinental Riyadh
# 235          "Plantation Bed and Breakfast
# 267                            Hotel Morón
# 343                    The Esplanade Hotel
# 458                Pousada Porto De Canoas
# 530                             AYAN MOTER
# 591                             Nag Aespen
# 641                          La Caz Oceane
# 663                        HOTEL EMBAJADOR
# 738                   Movenpick Hotel Doha
# 806                      The Irish Village
# 894                  Lamar Resort Abu Soma
# 1062                     Hotel - Miro Park
# 1166                     Shelly Bay Resort
# 1304                               Paihuen
# 1344              Seattle Marriott Redmond
# 1347                        Personal Hotel
# 1396                  Charme Hotel Guarujá
# 1424                     Bouganville Hotel
# 1473                  Praia Hotel Imbituba
# 1574                        Hotel Biarritz
# 1680                 Tarumã Tropical Hotel
# 1733                Grand Hotel Río Cuarto
# 1822                           فندق الدويم
# 1824                     Bam Tourist Hotel
# 1918                Swiss Belhotel Sharjah
# 1954  Howard Johnson Plaza Hotel Mayorazgo
# 1960            Los Muelles Boutique Hotel
# 1993                     Coral Sands Hotel
# 2006                          Hotel Raices
# 2046                   Grand hotel "Quena"
# 2071                       Rock Sound Club
# 2099           Mission studies boys hostel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
